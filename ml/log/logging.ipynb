# %%
import logging as l

l.basicConfig(level=l.DEBUG)

l.debug("This is debug message")
l.info("This is an info message")
l.warning("This is a warning message")
l.error("This is an error message")
l.critical("This is a critical message")
# Out:
# 2025-06-10 12:55:29,253 - DEBUG - This is debug message
# 2025-06-10 12:55:29,254 - INFO - This is an info message
# 2025-06-10 12:55:29,256 - WARNING - This is a warning message
# 2025-06-10 12:55:29,256 - ERROR - This is an error message
# 2025-06-10 12:55:29,257 - CRITICAL - This is a critical message

# %%
import logging 
logging.basicConfig(
    level=logging.DEBUG,
    format= '%(asctime)s - %(levelname)s - %(message)s'
)
logging.debug("This is debug message")
# Out:
# 2025-06-10 13-04-23 - DEBUG - This is debug message

# %%
import logging   # to store the result in the file
logging.basicConfig(
    filename='app.log',
    filemode= 'w',
    level= logging.DEBUG,
    format = '%(asctime)s - %(levelname)s - %(message)s',
    datefmt ="%Y-%m-%d %H-%M-%S"
)
logging.debug("This is debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

# %%
import logging 


logger1 = logging.getLogger("module1") ## This module1 is our wish (user defined one)
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)


level = logging.basicConfig(
    level = logging.DEBUG,
    format= '%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt="%Y-%m-%d %H:%M:%S"
)

logger1.debug("The debug for m1")
logger1.warning("The war for m1")
# Out:
# 2025-06-10 14:09:16 - module1 - DEBUG - The debug for m1
# 2025-06-10 14:09:16 - module1 - WARNING - The war for m1

# %%
print('saga.txt'.__sizeof__())
# Out:
# 49

# %%
import os
os.path.getsize('saga.txt')
# Out:
# 68

# %%
import logging
from logging.handlers import RotatingFileHandler


def create_logger():
    logger = logging.getLogger("rotatingfilehandler")
    logger.setLevel(logging.DEBUG)

    handler =  RotatingFileHandler(
        'rotating_app.log',
        maxBytes = 1048576,
        backupCount = 0
    )

    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)

    if not logger.handlers:
        logger.addHandler(handler)
    return logger
logger = create_logger()
for i in range(10000):
    logger.debug(f"log message {i}")
# Out:
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 0
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 1
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 2
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 3
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 4
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 5
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 6
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 7
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 8
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 9
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 10
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 11
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 12
# 2025-06-10 16:47:46 - rotatingfilehandler - DEBUG - log message 13
# ...

# %%
import logging
from logging.handlers import RotatingFileHandler
def n_rotating_logger():
    logger = logging.getLogger("roataingmany")
    logger.setLevel(logging.DEBUG)

    handler  = RotatingFileHandler(
        'rotating_app.log',
        maxBytes= 1024,
        backupCount= 3
    )

    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)

    if not logger.handlers:
        logger.addHandler(handler)
    
    return logger


logger = n_rotating_logger()
for i in range(100):
    logger.debug(f"The log is {i}")

# %%
import os
files = ['rotating_app.log','rotating_app.log.1','rotating_app.log.2','rotating_app.log.3']
for i in files:
    print(os.path.getsize(i))
# Out:
# 768
# 1024
# 1024
# 1024

# %%
import logging

def log_exception_error_level():
    try:
        
        1 / 0  
    except Exception as e:
        logger = logging.getLogger("log")
        logger.setLevel(logging.DEBUG)
        logging.basicConfig(
            filename='app.log',
            filemode='w', 
            level=logging.ERROR,
            format='%(asctime)s - %(levelname)s - %(message)s'
        )
        
        logging.error('Exception occurred', exc_info=True)

        return logger
logger = log_exception_error_level()
print(logger)
# Out:
# <Logger log (DEBUG)>

# %%
import logging

# Configure logging globally
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt= "%Y-%m-%d  %H:%M:%S",
    handlers=[
        logging.FileHandler('app.log'),
        logging.StreamHandler()   
    ]
)

def log_exception_error_level():
    logger = logging.getLogger("log")
    try:
        1 / 0
    except Exception as e:
        logger.error('Exception occurred',exc_info=True)
    return logger

logger = log_exception_error_level()
